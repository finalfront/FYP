# %%
import openai
from openai import AzureOpenAI
client = AzureOpenAI(
    api_key="*************************",
    api_version="2025-02-01-preview",
    azure_endpoint="https://hkust.azure-api.net"
)

# %%
with open("output.txt", "r", encoding="utf-8") as f:
    retrosynthesis_text = f.read()

system_prompt = """
You are a green chemistry expert.

You receive textual descriptions of many retrosynthesis routes ("graphs") to the same target molecule. 
Each route is labeled like "=== Graph 1 ===", "=== Graph 2 ===", etc., and contains a line 
starting with "Atom economy: XX.XX%" that gives the atom economy of that route.

Your task:
1. Parse all graphs and extract:
   - graph_id (integer after "Graph ")
   - atom_economy_percent (float value from the line "Atom economy: XX.XX%")

2. Evaluate "greenness" ONLY based on atom economy.
   - Higher atom economy means greener route.
   - Lower number of reactions means greener route.
   - Ignore all other metrics (precursor cost, number of reactions, depth, etc.) for this task.

3. Rank all routes from greenest to least green based on atom_economy_percent (descending).

4. Output ONLY a JSON array (no extra text), where each element is:
   {
     "graph_id": <int>,
     "score of number of reaction": <int>, 
     "score of atom_economy_percent": <float>, // keep the score to 1-10
     "rank": <int>   // 1 = greenest (highest atom economy)
   }

Additional rules:
- If two routes have exactly the same atom economy, assign them the same rank and keep any order.
- Do NOT include any explanation or extra text outside the JSON.
- If there is any parsing ambiguity, do your best guess and still output strictly valid JSON.
"""

# %%
few_shot_user_1 = """=== Graph 1 ===
Depth: 1
Number of reactions: 1
Precursor cost: 14.2
Atom economy: 77.48%
Target: CCOC(=O)c1ccc(N)cc1

=== Graph 2 ===
Depth: 1
Number of reactions: 1
Precursor cost: 1
Atom economy: 85.06%
Target: CCOC(=O)c1ccc(N)cc1

=== Graph 3 ===
Depth: 1
Number of reactions: 1
Precursor cost: 2
Atom economy: 56.54%
Target: CCOC(=O)c1ccc(N)cc1
"""

few_shot_assistant_1 = """[
  {
     "graph_id": <int>,
     "score of number of reaction": <int>
     "score of atom_economy_percent": <float>,
     "rank": <int>   // 1 = greenest (highest atom economy)

    "graph_id": <int>,
     "score of number of reaction": <int>
     "score of atom_economy_percent": <float>,
     "rank": <int>   // 1 = greenest (highest atom economy)

    "graph_id": <int>,
     "score of number of reaction": <int>
     "score of atom_economy_percent": <float>,
     "rank": <int>   // 1 = greenest (highest atom economy)
  }
]"""

# %%
few_shot_user_2 = """=== Graph 10 ===
Depth: 1
Number of reactions: 1
Precursor cost: 0.2
Atom economy: 98.84%
Target: CCOC(=O)c1ccc(N)cc1

=== Graph 11 ===
Depth: 1
Number of reactions: 1
Precursor cost: 14.23
Atom economy: 98.84%
Target: CCOC(=O)c1ccc(N)cc1

=== Graph 12 ===
Depth: 1
Number of reactions: 1
Precursor cost: 1.2
Atom economy: 82.11%
Target: CCOC(=O)c1ccc(N)cc1
"""

few_shot_assistant_2 = """[
  {
    "graph_id": 10,
    "atom_economy_percent": 98.84,
    "rank": 1
  },
  {
    "graph_id": 11,
    "atom_economy_percent": 98.84,
    "rank": 1
  },
  {
    "graph_id": 12,
    "atom_economy_percent": 82.11,
    "rank": 2
  }
]"""

# %%
messages = [
    {"role": "system", "content": system_prompt},

    # few-shot example 1
    #{"role": "user", "content": few_shot_user_1},
    #{"role": "assistant", "content": few_shot_assistant_1},

    # few-shot example 2
    #{"role": "user", "content": few_shot_user_2},
    #{"role": "assistant", "content": few_shot_assistant_2},

    # 真实任务：把整个 output.txt 丢进去
    {"role": "user", "content": retrosynthesis_text}
]

response = client.chat.completions.create(
    model="o4-mini",
    messages=messages,
)

print(response.choices[0].message.content)
# Out:
# [{"graph_id":11,"score of number of reaction":1,"score of atom_economy_percent":10.0,"rank":1},
# {"graph_id":10,"score of number of reaction":1,"score of atom_economy_percent":9.9,"rank":2},
# {"graph_id":44,"score of number of reaction":2,"score of atom_economy_percent":9.8,"rank":3},
# {"graph_id":19,"score of number of reaction":1,"score of atom_economy_percent":9.8,"rank":4},
# {"graph_id":37,"score of number of reaction":2,"score of atom_economy_percent":9.2,"rank":5},
# {"graph_id":14,"score of number of reaction":1,"score of atom_economy_percent":9.1,"rank":6},
# {"graph_id":73,"score of number of reaction":2,"score of atom_economy_percent":9.1,"rank":6},
# {"graph_id":8,"score of number of reaction":1,"score of atom_economy_percent":9.0,"rank":8},
# {"graph_id":28,"score of number of reaction":2,"score of atom_economy_percent":9.0,"rank":8},
# {"graph_id":13,"score of number of reaction":1,"score of atom_economy_percent":8.5,"rank":10},
# {"graph_id":2,"score of number of reaction":1,"score of atom_economy_percent":8.5,"rank":11},
# {"graph_id":32,"score of number of reaction":2,"score of atom_economy_percent":8.5,"rank":11},
# {"graph_id":5,"score of number of reaction":1,"score of atom_economy_percent":8.5,"rank":13},
# {"graph_id":70,"score of number of reaction":2,"score of atom_economy_percent":8.5,"rank":13},
# {"graph_id":15,"score of number of reaction":1,"score of atom_economy_percent":8.4,"rank":15},
# {"graph_id":12,"score of number of reaction":1,"score of atom_economy_percent":8.2,"rank":16},
# {"graph_id":17,"score of number of reaction":1,"score of atom_economy_percent":8.0,"rank":17},
# {"graph_id":87,"score of number of reaction":3,"score of atom_economy_percent":7.9,"rank":18},
# {"graph_id":36,"score of number of reaction":2,"score of atom_economy_percent":7.9,"rank":19},
# {"graph_id":1,"score of number of reaction":1,"score of atom_economy_percent":7.7,"rank":20},
# {"graph_id":9,"score of number of reaction":1,"score of atom_economy_percent":7.2,"rank":21},
# {"graph_id":38,"score of number of reaction":2,"score of atom_economy_percent":7.2,"rank":21},
# {"graph_id":63,"score of number of reaction":2,"score of atom_economy_percent":7.1,"rank":23},
# {"graph_id":34,"score of number of reaction":2,"score of atom_economy_percent":6.9,"rank":24},
# {"graph_id":18,"score of number of reaction":1,"score of atom_economy_percent":6.8,"rank":25},
# {"graph_id":20,"score of number of reaction":1,"score of atom_economy_percent":6.7,"rank":26},
# {"graph_id":64,"score of number of reaction":2,"score of atom_economy_percent":6.7,"rank":27},
# {"graph_id":61,"score of number of reaction":2,"score of atom_economy_percent":6.6,"rank":28},
# {"graph_id":59,"score of number of reaction":2,"score of atom_economy_percent":6.3,"rank":29},
# {"graph_id":16,"score of number of reaction":1,"score of atom_economy_percent":6.3,"rank":30},
# {"graph_id":60,"score of number of reaction":2,"score of atom_economy_percent":6.3,"rank":31},
# {"graph_id":66,"score of number of reaction":2,"score of atom_economy_percent":6.2,"rank":32},
# {"graph_id":6,"score of number of reaction":1,"score of atom_economy_percent":6.2,"rank":33},
# {"graph_id":39,"score of number of reaction":2,"score of atom_economy_percent":6.1,"rank":34},
# {"graph_id":4,"score of number of reaction":1,"score of atom_economy_percent":6.0,"rank":35},
# {"graph_id":33,"score of number of reaction":2,"score of atom_economy_percent":6.0,"rank":35},
# {"graph_id":31,"score of number of reaction":2,"score of atom_economy_percent":6.0,"rank":37},
# {"graph_id":62,"score of number of reaction":2,"score of atom_economy_percent":6.0,"rank":38},
# {"graph_id":88,"score of number of reaction":3,"score of atom_economy_percent":5.9,"rank":39},
# {"graph_id":53,"score of number of reaction":2,"score of atom_economy_percent":5.9,"rank":40},
# {"graph_id":3,"score of number of reaction":1,"score of atom_economy_percent":5.7,"rank":41},
# {"graph_id":54,"score of number of reaction":2,"score of atom_economy_percent":5.6,"rank":42},
# {"graph_id":51,"score of number of reaction":2,"score of atom_economy_percent":5.6,"rank":43},
# {"graph_id":78,"score of number of reaction":2,"score of atom_economy_percent":5.6,"rank":43},
# {"graph_id":79,"score of number of reaction":2,"score of atom_economy_percent":5.6,"rank":43},
# {"graph_id":58,"score of number of reaction":2,"score of atom_economy_percent":5.5,"rank":46},
# {"graph_id":21,"score of number of reaction":2,"score of atom_economy_percent":5.5,"rank":47},
# {"graph_id":42,"score of number of reaction":2,"score of atom_economy_percent":5.4,"rank":48},
# {"graph_id":49,"score of number of reaction":2,"score of atom_economy_percent":5.3,"rank":49},
# {"graph_id":72,"score of number of reaction":2,"score of atom_economy_percent":5.3,"rank":50},
# {"graph_id":29,"score of number of reaction":2,"score of atom_economy_percent":5.2,"rank":51},
# {"graph_id":24,"score of number of reaction":2,"score of atom_economy_percent":5.2,"rank":52},
# {"graph_id":52,"score of number of reaction":2,"score of atom_economy_percent":5.1,"rank":53},
# {"graph_id":40,"score of number of reaction":2,"score of atom_economy_percent":5.2,"rank":54},
# {"graph_id":23,"score of number of reaction":2,"score of atom_economy_percent":4.9,"rank":55},
# {"graph_id":49,"score of number of reaction":2,"score of atom_economy_percent":5.3,"rank":49},
# {"graph_id":35,"score of number of reaction":2,"score of atom_economy_percent":4.8,"rank":57},
# {"graph_id":47,"score of number of reaction":2,"score of atom_economy_percent":4.5,"rank":58},
# {"graph_id":41,"score of number of reaction":2,"score of atom_economy_percent":4.5,"rank":59},
# {"graph_id":46,"score of number of reaction":2,"score of atom_economy_percent":4.0,"rank":60},
# {"graph_id":48,"score of number of reaction":2,"score of atom_economy_percent":4.2,"rank":61},
# {"graph_id":76,"score of number of reaction":2,"score of atom_economy_percent":4.1,"rank":62},
# {"graph_id":77,"score of number of reaction":2,"score of atom_economy_percent":4.2,"rank":63},
# {"graph_id":69,"score of number of reaction":2,"score of atom_economy_percent":4.8,"rank":64},
# {"graph_id":71,"score of number of reaction":2,"score of atom_economy_percent":4.8,"rank":65},
# {"graph_id":45,"score of number of reaction":2,"score of atom_economy_percent":3.6,"rank":66},
# {"graph_id":30,"score of number of reaction":2,"score of atom_economy_percent":3.8,"rank":67},
# {"graph_id":26,"score of number of reaction":2,"score of atom_economy_percent":3.7,"rank":68},
# {"graph_id":65,"score of number of reaction":2,"score of atom_economy_percent":3.6,"rank":69},
# {"graph_id":67,"score of number of reaction":2,"score of atom_economy_percent":3.6,"rank":69},
# {"graph_id":82,"score of number of reaction":3,"score of atom_economy_percent":3.3,"rank":71},
# {"graph_id":85,"score of number of reaction":3,"score of atom_economy_percent":3.3,"rank":72},
# {"graph_id":81,"score of number of reaction":3,"score of atom_economy_percent":3.2,"rank":73},
# {"graph_id":86,"score of number of reaction":3,"score of atom_economy_percent":3.0,"rank":74},
# {"graph_id":80,"score of number of reaction":3,"score of atom_economy_percent":2.3,"rank":75},
# {"graph_id":83,"score of number of reaction":3,"score of atom_economy_percent":2.2,"rank":76},
# {"graph_id":84,"score of number of reaction":3,"score of atom_economy_percent":2.6,"rank":77},
# {"graph_id":89,"score of number of reaction":3,"score of atom_economy_percent":2.9,"rank":78},
# {"graph_id":22,"score of number of reaction":2,"score of atom_economy_percent":3.2,"rank":79},
# {"graph_id":25,"score of number of reaction":2,"score of atom_economy_percent":3.0,"rank":80},
# {"graph_id":27,"score of number of reaction":2,"score of atom_economy_percent":4.3,"rank":58},
# {"graph_id":56,"score of number of reaction":2,"score of atom_economy_percent":5.3,"rank":51},
# {"graph_id":57,"score of number of reaction":2,"score of atom_economy_percent":3.2,"rank":73},
# {"graph_id":68,"score of number of reaction":2,"score of atom_economy_percent":6.6,"rank":31},
# {"graph_id":66,"score of number of reaction":2,"score of atom_economy_percent":6.2,"rank":32},
# {"graph_id":88,"score of number of reaction":3,"score of atom_economy_percent":5.9,"rank":39},
# {"graph_id":49,"score of number of reaction":2,"score of atom_economy_percent":5.3,"rank":49},
# {"graph_id":50,"score of number of reaction":2,"score of atom_economy_percent":5.3,"rank":52},
# {"graph_id":52,"score of number of reaction":2,"score of atom_economy_percent":5.1,"rank":53},
# {"graph_id":53,"score of number of reaction":2,"score of atom_economy_percent":5.9,"rank":40},
# {"graph_id":54,"score of number of reaction":2,"score of atom_economy_percent":5.6,"rank":42},
# {"graph_id":55,"score of number of reaction":2,"score of atom_economy_percent":3.3,"rank":82},
# {"graph_id":56,"score of number of reaction":2,"score of atom_economy_percent":5.3,"rank":51},
# {"graph_id":57,"score of number of reaction":2,"score of atom_economy_percent":3.3,"rank":82},
# {"graph_id":58,"score of number of reaction":2,"score of atom_economy_percent":5.5,"rank":46},
# {"graph_id":59,"score of number of reaction":2,"score of atom_economy_percent":6.3,"rank":29},
# {"graph_id":60,"score of number of reaction":2,"score of atom_economy_percent":6.3,"rank":31},
# {"graph_id":61,"score of number of reaction":2,"score of atom_economy_percent":6.6,"rank":28},
# {"graph_id":62,"score of number of reaction":2,"score of atom_economy_percent":6.0,"rank":38},
# {"graph_id":63,"score of number of reaction":2,"score of atom_economy_percent":7.1,"rank":23},
# {"graph_id":64,"score of number of reaction":2,"score of atom_economy_percent":6.7,"rank":26},
# {"graph_id":65,"score of number of reaction":2,"score of atom_economy_percent":3.6,"rank":69},
# {"graph_id":66,"score of number of reaction":2,"score of atom_economy_percent":6.2,"rank":32},
# {"graph_id":67,"score of number of reaction":2,"score of atom_economy_percent":3.6,"rank":69},
# {"graph_id":68,"score of number of reaction":2,"score of atom_economy_percent":6.6,"rank":28},
# {"graph_id":69,"score of number of reaction":2,"score of atom_economy_percent":4.8,"rank":64},
# {"graph_id":70,"score of number of reaction":2,"score of atom_economy_percent":8.5,"rank":13},
# {"graph_id":71,"score of number of reaction":2,"score of atom_economy_percent":4.8,"rank":65},
# {"graph_id":72,"score of number of reaction":2,"score of atom_economy_percent":5.3,"rank":50},
# {"graph_id":73,"score of number of reaction":2,"score of atom_economy_percent":9.1,"rank":6},
# {"graph_id":74,"score of number of reaction":2,"score of atom_economy_percent":6.5,"rank":30},
# {"graph_id":75,"score of number of reaction":2,"score of atom_economy_percent":6.6,"rank":29},
# {"graph_id":76,"score of number of reaction":2,"score of atom_economy_percent":4.1,"rank":62},
# {"graph_id":77,"score of number of reaction":2,"score of atom_economy_percent":4.2,"rank":63},
# {"graph_id":78,"score of number of reaction":2,"score of atom_economy_percent":5.6,"rank":43},
# {"graph_id":79,"score of number of reaction":2,"score of atom_economy_percent":5.6,"rank":43},
# {"graph_id":80,"score of number of reaction":3,"score of atom_economy_percent":2.3,"rank":75},
# {"graph_id":81,"score of number of reaction":3,"score of atom_economy_percent":3.2,"rank":73},
# {"graph_id":82,"score of number of reaction":3,"score of atom_economy_percent":3.3,"rank":71},
# {"graph_id":83,"score of number of reaction":3,"score of atom_economy_percent":2.2,"rank":76},
# {"graph_id":84,"score of number of reaction":3,"score of atom_economy_percent":2.6,"rank":77},
# {"graph_id":85,"score of number of reaction":3,"score of atom_economy_percent":3.3,"rank":72},
# {"graph_id":86,"score of number of reaction":3,"score of atom_economy_percent":3.0,"rank":74},
# {"graph_id":87,"score of number of reaction":3,"score of atom_economy_percent":7.9,"rank":18},
# {"graph_id":88,"score of number of reaction":3,"score of atom_economy_percent":5.9,"rank":39},
# {"graph_id":89,"score of number of reaction":3,"score of atom_economy_percent":2.9,"rank":78}]
